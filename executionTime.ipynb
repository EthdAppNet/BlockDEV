# %%
#order registration
import time
# Initialize lists to store the results
E_values = [50000]  # Initialize with the initial value of E
p_values = []
order_array = []
# Initial values
E = 50000
L = 50000

#order registrer time calculation starts here
start_time_order_register = time.time()
Delta_e = 100
order1 = Delta_e
order_array.append(order1)

#order register time calculation ends here
end_time_order_register = time.time()


#CPMM time calculation starts here-------------------------------------------
start_time_CPMM = time.time()
# Calculate delta_m
delta_m = L * Delta_e / (E + Delta_e)

# Update E and L
E = E + Delta_e
L = L - delta_m

# Calculate the new price
P_new = L / E

# Append the calculated E and P_new to their respective lists
E_values.append(E)
p_values.append(P_new)



end_time_CPMM = time.time()
#CPMM time calculation ends here------------------------------------

#Get price calculation start here------------------------------------
start_time_get_price = time.time()
#get price function
#print("Updated P_new:", P_new)
end_time_get_price = time.time()
#Get price calculation start here------------------------------------



# Calculate the execution time
execution_time_order_register = (end_time_order_register - start_time_order_register)*1000
execution_time_CPMM = (end_time_CPMM - start_time_CPMM)*1000
execution_time_get_price = (end_time_get_price - start_time_get_price)*1000


print("execution_time_order_register:", execution_time_order_register, "milliseconds")
print("execution_time_CPMM:", execution_time_CPMM, "milliseconds")
print("execution_time_get_price:", execution_time_get_price, "milliseconds")
# Out:
# execution_time_order_register: 0.08130073547363281 milliseconds
# execution_time_CPMM: 0.17261505126953125 milliseconds
# execution_time_get_price: 0.018835067749023438 milliseconds

# %%
execution_time_order_register1= 0.09894371032714844
execution_time_CPMM1= 0.20360946655273438
execution_time_get_price1= 0.019311904907226562

execution_time_order_register2= 0.07915496826171875
execution_time_CPMM2= 0.1480579376220703
execution_time_get_price2= 0.018596649169921875

execution_time_order_register3= 0.08130073547363281
execution_time_CPMM3= 0.17261505126953125
execution_time_get_price3= 0.018835067749023438

avg_execution_time_order_register = (execution_time_order_register1 + execution_time_order_register2 + execution_time_order_register3 )/3
avg_execution_time_CPMM = (execution_time_CPMM1 + execution_time_CPMM2 + execution_time_CPMM3 )/3
avg_execution_time_get_price = (execution_time_get_price1 + execution_time_get_price2  +execution_time_get_price3) /3
print("avg_execution_time_order_register",avg_execution_time_order_register)
print("avg_execution_time_CPMM", avg_execution_time_CPMM)
print("avg_execution_time_get_price", avg_execution_time_get_price)
# Out:
# avg_execution_time_order_register 0.08646647135416667
# avg_execution_time_CPMM 0.1747608184814453
# avg_execution_time_get_price 0.018914540608723957

# %%
#selection function
import random
import math
import time
class CostFactors:
    def __init__(self, monetary_cost, traveling_time_cost, charging_time_cost, waiting_time_cost, reputation_score_cost):
        self.monetary_cost = monetary_cost
        self.traveling_time_cost = traveling_time_cost
        self.charging_time_cost = charging_time_cost
        self.waiting_time_cost = waiting_time_cost
        self.reputation_score_cost = reputation_score_cost

    def __str__(self):
        return f"Monetary Cost: {self.monetary_cost}\nTraveling Time Cost: {self.traveling_time_cost}\nCharging Time Cost: {self.charging_time_cost}\nWaiting Time Cost: {self.waiting_time_cost}\nReputation Score Cost: {self.reputation_score_cost}"

# Create a list to store the instances
cost_factors_list = []
download_list =[]

# Generate 50 instances with random cost factors
for i in range(1, 3):
  monetary_cost = random.randint(1, 100)
  traveling_time_cost = random.randint(1, 50)
  charging_time_cost = random.randint(1, 20)
  waiting_time_cost = random.randint(1, 10)
  reputation_score_cost = random.randint(1, 5)

  A = CostFactors(monetary_cost, traveling_time_cost, charging_time_cost, waiting_time_cost, reputation_score_cost)

    # Append the instance to the list
  cost_factors_list.append(A)

#Calculate time for get_order function
start_time_get_order=time.time()

download_list=cost_factors_list

end_time_get_order=time.time()

start_time_select_mod=time.time()

print(cost_factors_list[1])
# A1 instance
A1 = cost_factors_list[0]

# Initialize variables to track the minimum distance and corresponding instance
min_distance = float('inf')  # Start with positive infinity
closest_instance = None

# Calculate Euclidean distance for each instance and find the closest one
for i, A in enumerate(cost_factors_list[1:], start=2):  # Start with A2
    distance = math.sqrt((A.monetary_cost - A1.monetary_cost) ** 2 +
                         (A.traveling_time_cost - A1.traveling_time_cost) ** 2 +
                         (A.charging_time_cost - A1.charging_time_cost) ** 2 +
                         (A.waiting_time_cost - A1.waiting_time_cost) ** 2 +
                         (A.reputation_score_cost - A1.reputation_score_cost) ** 2)

    if distance < min_distance:
        min_distance = distance
        closest_instance = A
        closest_name = f"A{i}"

end_time_select_mod=time.time()

execution_time_get_order=(end_time_get_order - start_time_get_order)*1000

execution_time_select_mod=(end_time_select_mod-start_time_select_mod)*1000\

# Print the closest instance and its name
#print(f"Closest Instance to A1 ({closest_name}):")
#print(closest_instance)
print("execution_time_get_order:", execution_time_get_order, "milliseconds")
print("execution_time_select_mod:", execution_time_select_mod, "milliseconds")
# Out:
# Monetary Cost: 42
# Traveling Time Cost: 34
# Charging Time Cost: 15
# Waiting Time Cost: 10
# Reputation Score Cost: 3
# execution_time_get_order: 0.08130073547363281 milliseconds
# execution_time_select_mod: 3.0145645141601562 milliseconds

# %%
execution_time_get_order1= 0.07104873657226562
execution_time_select_mod1= 0.8761882781982422
execution_time_get_order2= 0.09560585021972656
execution_time_select_mod2= 1.7576217651367188
execution_time_get_order3= 0.08130073547363281
execution_time_select_mod3= 3.0145645141601562

avg_execution_time_get_order = (execution_time_get_order1 + execution_time_get_order2 + execution_time_get_order3)/3
avg_execution_time_select_mod = (execution_time_select_mod1 + execution_time_select_mod2 + execution_time_select_mod3)/3

print("avg_execution_time_get_order", avg_execution_time_get_order)
print("avg_execution_time_select_mod", avg_execution_time_select_mod)
# Out:
# avg_execution_time_get_order 0.08265177408854167
# avg_execution_time_select_mod 1.882791519165039

# %%
#reservation function
import time
bid = [1, False]
transaction = []
reservation = []
start_time_reserve=time.time()
# Check if the bid is False (i.e., not taken)
if bid[1] == False:
    # Add an entry to the transaction array
    transaction.append(bid[0])
    # Add an entry to the reservation array
    reservation.append(bid[0])
    # Change the first value of the bid from 1 to 0
    bid[0] = 0

# Print the updated bid, transaction, and reservation arrays
print("Updated bid:", bid)
print("Transaction array:", transaction)
print("Reservation array:", reservation)
end_time_reserve=time.time()
execution_time_reserve=(end_time_reserve-start_time_reserve)*1000
print("execution_time_reserve", execution_time_reserve, "miliseconds")
# Out:
# Updated bid: [0, False]
# Transaction array: [1]
# Reservation array: [1]
# execution_time_reserve 0.46443939208984375 miliseconds

# %%
execution_time_reserve1 = 0.31065940856933594
execution_time_reserve2 = 0.5350112915039062
execution_time_reserve3 = 0.46443939208984375
avg_execution_time_reserve = (execution_time_reserve1 + execution_time_reserve2 + execution_time_reserve3)/3
print ("avg_execution_time_reserve:", avg_execution_time_reserve)
# Out:
# avg_execution_time_reserve: 0.436703364054362

# %%
#payment function
import time

start_time_payment = time.time()
charging = True

# Initialize the transaction and deposit arrays
transaction = []
deposit = []

# Check if charging is True
if charging:
    # Add "provider" to the transaction array
    transaction.append("provider")
    # Add "v" to the deposit array
    deposit.append("v")

    end_time_payment = time.time()
    execution_time_payment = (end_time_payment - start_time_payment) *1000

print("execution_time_payment", execution_time_payment, "miliseconds")
# Out:
# execution_time_payment 0.2524852752685547 miliseconds

# %%
execution_time_payment1= 0.2071857452392578
execution_time_payment2 =0.22792816162109375
execution_time_payment3= 0.2524852752685547
avg_execution_time_payment = (execution_time_payment1 + execution_time_payment2 + execution_time_payment3)/3
print ("avg_execution_time_payment:" , avg_execution_time_payment)
# Out:
# avg_execution_time_payment: 0.2291997273763021

# %%
#Reputation function
import math
# Initial values
import time
p0 = 0.8
r = 1.0

# Calculate p1
start_time_reputation = time.time()
p1 =  math.exp( - 100.0 * 50.0)

# Calculate p2
p2 = 1.0 / (1.0 + r *  math.exp ( - 50.0 * p1))

# Create an array and push p2 into it
result_array = []
result_array.append(p2)
end_time_reputation = time.time()
execution_time_reputation=(end_time_reputation-start_time_reputation)*1000
# Print the results

print("execution_time_reputation:", execution_time_reputation, "miliseconds")
# Out:
# execution_time_reputation: 0.11086463928222656 miliseconds

# %%
execution_time_reputation1= 0.24962425231933594
execution_time_reputation2= 0.2009868621826172
execution_time_reputation3= 0.11086463928222656
avg_execution_time_reputation = (execution_time_reputation1 + execution_time_reputation2 + execution_time_reputation3) / 3
print("avg_execution_time_reputation:", avg_execution_time_reputation, "miliseconds")
# Out:
# avg_execution_time_reputation: 0.18715858459472656 miliseconds

# %%
import matplotlib.pyplot as plt
execution_times = [avg_execution_time_order_register , avg_execution_time_CPMM ,avg_execution_time_get_price  ,avg_execution_time_get_order , avg_execution_time_select_mod , avg_execution_time_reserve, avg_execution_time_payment, avg_execution_time_reputation]

# Create a list of labels for the x-axis
labels = ["Order_Register", "CPMM", "Get_price",  "Get_Orders", "Selection_Optimization", "Reservation", "Payment", "Reputation"]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#d62728']
# Create a figure and plot the data
plt.figure(figsize=(10, 6))
plt.bar(labels, execution_times, color=colors, width=0.3)
plt.xticks(rotation=-30)
# Set labels and title
plt.xlabel("Functions")
plt.ylabel("Execution Time (ms)")
#plt.title("Execution Times for 7 Tasks")

# Show the plot
plt.grid(True)
plt.savefig('execTime.jpg', dpi=300, bbox_inches='tight')
plt.show()
from google.colab import files
files.download('execTime.jpg')

# %%
total_execution_time_1CS = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation
print (total_execution_time_1CS)
# Out:
# 3.098646799723307

# %%
total_execution_time_1CS = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation
print (total_execution_time_1CS)

total_execution_time_50CS = avg_execution_time_order_register + avg_execution_time_CPMM  +  avg_execution_time_get_price  + 50* avg_execution_time_get_order + 50*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation
print (total_execution_time_50CS)

total_execution_time_100CS = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 100* avg_execution_time_get_order + 100* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation
print (total_execution_time_100CS)

total_execution_time_150CS = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 150* avg_execution_time_get_order + 150* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation
print (total_execution_time_150CS)

total_execution_time_200CS = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 200 *avg_execution_time_get_order + 200*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation
print (total_execution_time_200CS)

import matplotlib.pyplot as plt
execution_times = [total_execution_time_1CS , total_execution_time_50CS ,total_execution_time_100CS  ,total_execution_time_150CS , total_execution_time_200CS]

# Create a list of labels for the x-axis
labels = ["1 CS", "50 CSs", "100 CSs",  "150 CSs", "200 CSs"]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
# Create a figure and plot the data
plt.figure(figsize=(10, 6))
plt.bar(labels, execution_times, color=colors, width=0.3)
plt.xticks(rotation=-30)
# Set labels and title
plt.xlabel("Number of CS")
plt.ylabel("Execution Time (ms)")
#plt.title("Execution Times for 7 Tasks")

# Show the plot
plt.grid(True)
plt.savefig('execTime_different_CS.jpg', dpi=300, bbox_inches='tight')
plt.show()
from google.colab import files
files.download('execTime_different_CS.jpg')
# Out:
# 3.098646799723307
# 99.40536816914876
# 197.6775328318278
# 295.94969749450684
# 394.22186215718585

# %%
#1 order
order1_CS_set1 = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order1_CS_set2 = avg_execution_time_order_register + avg_execution_time_CPMM  +  avg_execution_time_get_price  + 50* avg_execution_time_get_order + 50*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order1_CS_set3 = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 100* avg_execution_time_get_order + 100* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order1_CS_set4 = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 150* avg_execution_time_get_order + 150* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order1_CS_set5 = avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 200 *avg_execution_time_get_order + 200*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order_1 = [ order1_CS_set1, order1_CS_set2, order1_CS_set3, order1_CS_set4,  order1_CS_set5 ]
print ("order_1", order_1)

#50 order
order50_CS_set1 = 50 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order50_CS_set2 = 50 *avg_execution_time_order_register + avg_execution_time_CPMM  +  avg_execution_time_get_price  + 50* avg_execution_time_get_order + 50*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation

order50_CS_set3 = 50 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 100* avg_execution_time_get_order + 100* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation

order50_CS_set4 = 50 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 150* avg_execution_time_get_order + 150* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation

order50_CS_set5 = 50 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 200 *avg_execution_time_get_order + 200*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order_50 = [ order50_CS_set1, order50_CS_set2, order50_CS_set3, order50_CS_set4,  order50_CS_set5 ]
print ("order_50", order_50)

#100 order
orde100_CS_set1 = 100 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order100_CS_set2 = 100 *avg_execution_time_order_register + avg_execution_time_CPMM  +  avg_execution_time_get_price  + 50* avg_execution_time_get_order + 50*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order100_CS_set3 = 100 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 100* avg_execution_time_get_order + 100* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order100_CS_set4 = 100 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 150* avg_execution_time_get_order + 150* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order100_CS_set5 = 100 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 200 *avg_execution_time_get_order + 200*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order_100 = [ order50_CS_set1, order100_CS_set2, order100_CS_set3, order100_CS_set4,  order100_CS_set5 ]
print ("order_100", order_100)

#150 order
orde150_CS_set1 = 150 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order150_CS_set2 = 150 *avg_execution_time_order_register + avg_execution_time_CPMM  +  avg_execution_time_get_price  + 50* avg_execution_time_get_order + 50*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation

order150_CS_set3 = 150 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 100* avg_execution_time_get_order + 100* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order150_CS_set4 = 150 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 150* avg_execution_time_get_order + 150* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order150_CS_set5 = 150 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 200 *avg_execution_time_get_order + 200*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order_150 = [ orde150_CS_set1, order150_CS_set2,order150_CS_set3, order150_CS_set4,  order150_CS_set5 ]
print ("order_150", order_150)


#200 order
orde200_CS_set1 = 200 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + avg_execution_time_get_order + avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order200_CS_set2 = 200 *avg_execution_time_order_register + avg_execution_time_CPMM  +  avg_execution_time_get_price  + 50* avg_execution_time_get_order + 50*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order200_CS_set3 = 200 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 100* avg_execution_time_get_order + 100* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order200_CS_set4 = 200 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 150* avg_execution_time_get_order + 150* avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation


order200_CS_set5 = 200 * avg_execution_time_order_register + avg_execution_time_CPMM  + avg_execution_time_get_price  + 200 *avg_execution_time_get_order + 200*avg_execution_time_select_mod + avg_execution_time_reserve+ avg_execution_time_payment+ avg_execution_time_reputation

order_200 = [ orde200_CS_set1, order200_CS_set2,order200_CS_set3, order200_CS_set4,  order200_CS_set5 ]
print ("order_200", order_200)

order_data = [order_1,order_50,order_100,order_150,order_200]

x_values = [ "1 CS", "50 CSs", "100 CSs", "150 CSs", "200 CSs"]
# Create a figure and plot the data for each line

line_styles = ['-', '--', '-.', ':', '-']



plt.figure(figsize=(10, 6))
plt.plot(x_values, order_1, color='#1f77b4', label='1 orders', linestyle='--', linewidth=2)
plt.plot(x_values, order_50, color='#ff7f0e', label='50 sell_orders', linestyle='-', linewidth=2)
plt.plot(x_values, order_100, color='#2ca02c', label='100 sell_orders', linestyle='-.', linewidth=2)
plt.plot(x_values, order_150, color='#d62728', label='150 sell_orders', linestyle='-', linewidth=2)
plt.plot(x_values, order_200, color='black', label='200 sell_orders', linestyle='--', linewidth=2)

# Set labels and title
plt.xlabel("Number of CSs")
plt.ylabel("Execution Time (ms)")
plt.grid(True)

# Add a legend
plt.legend()

# Save the plot to a file
plt.savefig('execTime_line_graph.jpg', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

from google.colab import files
files.download('execTime_line_graph.jpg')
# Out:
# order_1 [3.098646799723307, 99.40536816914876, 197.6775328318278, 295.94969749450684, 394.22186215718585]
# order_50 [7.3355038960774746, 103.64222526550293, 201.91438992818198, 300.186554590861, 398.45871925354004]
# order_100 [7.3355038960774746, 107.96554883321127, 206.23771349589032, 304.50987815856934, 402.78204282124835]
# order_150 [15.98215103149414, 112.2888724009196, 210.56103706359863, 308.83320172627765, 407.1053663889567]
# order_200 [20.305474599202476, 116.61219596862793, 214.88436063130698, 313.156525293986, 411.42868995666504]

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_values, order_1, color='#1f77b4', label='1 orders', linestyle='-', linewidth=2)
plt.plot(x_values, order_50, color='#ff7f0e', label='50 sell_orders', linestyle='-', linewidth=2)
plt.plot(x_values, order_100, color='#2ca02c', label='100 sell_orders', linestyle='-', linewidth=2)
plt.plot(x_values, order_150, color='#d62728', label='150 sell_orders', linestyle='-', linewidth=2)
plt.plot(x_values, order_200, color='#2ca02b', label='200 sell_orders', linestyle='-', linewidth=2)

# Set labels and title
plt.xlabel("Tasks")
plt.ylabel("Execution Time (ms)")
plt.grid(True)

# Add a legend
plt.legend()

# Save the plot to a file
plt.savefig('execTime_line_graph.jpg', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

from google.colab import files
files.download('execTime_line_graph.jpg')
